# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv("/content/heart.csv.csv")
dff=pd.read_csv("/content/heart1.csv")
print(df)
print(dff)
# Out:
#      age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0     63    1   3     145   233    1        0       150     0      2.3    0
# 1     37    1   2     130   250    0        1       187     0      3.5    0
# 2     41    0   1     130   204    0        0       172     0      1.4    2
# 3     56    1   1     120   236    0        1       178     0      0.8    2
# 4     57    0   0     120   354    0        1       163     1      0.6    2
# ..   ...  ...  ..     ...   ...  ...      ...       ...   ...      ...  ...
# 160   56    1   1     120   240    0        1       169     0      0.0    0
# 161   55    0   1     132   342    0        1       166     0      1.2    2
# 162   41    1   1     120   157    0        1       182     0      0.0    2
# 163   38    1   2     138   175    0        1       173     0      0.0    2
# 164   38    1   2     138   175    0        1       173     0      0.0    2
#
#      caa  thall  output
# 0      0      1       1
# ...

# %%
df.head(10)
# Out:
#    age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0   63    1   3     145   233    1        0       150     0      2.3    0
# 1   37    1   2     130   250    0        1       187     0      3.5    0
# 2   41    0   1     130   204    0        0       172     0      1.4    2
# 3   56    1   1     120   236    0        1       178     0      0.8    2
# 4   57    0   0     120   354    0        1       163     1      0.6    2
# 5   57    1   0     140   192    0        1       148     0      0.4    1
# 6   56    0   1     140   294    0        0       153     0      1.3    1
# 7   44    1   1     120   263    0        1       173     0      0.0    2
# 8   52    1   2     172   199    1        1       162     0      0.5    2
# 9   57    1   2     150   168    0        1       174     0      1.6    2
#
#    caa  thall  output
# 0    0      1       1
# 1    0      2       1
# 2    0      2       1
# 3    0      2       1
# 4    0      2       1
# ...

# %%
dff.head(10)
# Out:
#    age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0   67    1   0     160   286    0        0       108     1      1.5    1
# 1   67    1   0     120   229    0        0       129     1      2.6    1
# 2   62    0   0     140   268    0        0       160     0      3.6    0
# 3   63    1   0     130   254    0        0       147     0      1.4    1
# 4   53    1   0     140   203    1        0       155     1      3.1    0
# 5   56    1   2     130   256    1        0       142     1      0.6    1
# 6   48    1   1     110   229    0        1       168     0      1.0    0
# 7   58    1   1     120   284    0        0       160     0      1.8    1
# 8   58    1   2     132   224    0        0       173     0      3.2    2
# 9   60    1   0     130   206    0        0       132     1      2.4    1
#
#    caa  thall  output
# 0    3      2       0
# 1    2      3       0
# 2    2      2       0
# 3    1      3       0
# 4    0      3       0
# ...

# %%
df.shape,dff.shape
# Out:
# ((165, 14), (138, 14))

# %%
df["class"]=1
dff["class"]=0

# %%
data_true_manual_testing=df.tail(5)
for i in range(9,4,-1):
  df.drop([i],axis=0, inplace=True)
data_fake_manual_testing=dff.tail(5)
for i in range(9,4,-1):
  dff.drop([i],axis=0,inplace=True)

# %%
data_manual_testing=pd.concat([data_fake_manual_testing,data_true_manual_testing],axis=0)
data_manual_testing.to_csv("manual_testing.csv")

# %%
data_merge=pd.concat([df,dff],axis=0)
data_merge.head(5)
# Out:
#    age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0   63    1   3     145   233    1        0       150     0      2.3    0
# 1   37    1   2     130   250    0        1       187     0      3.5    0
# 2   41    0   1     130   204    0        0       172     0      1.4    2
# 3   56    1   1     120   236    0        1       178     0      0.8    2
# 4   57    0   0     120   354    0        1       163     1      0.6    2
#
#    caa  thall  output  class
# 0    0      1       1      1
# 1    0      2       1      1
# 2    0      2       1      1
# 3    0      2       1      1
# 4    0      2       1      1

# %%
print(data_merge.groupby(['age'])['output'].count())
data_merge.groupby(['age'])['output'].count().plot(kind="bar")
plt.title("heart rate according to their age")
plt.show()
# Out:
# age
# 29     1
# 34     2
# 35     4
# 37     2
# 38     3
# 39     4
# 40     3
# 41    10
# 42     8
# 43     8
# 44    10
# 45     8
# 46     7
# 47     5
# 48     6
# 49     5
# 50     7
# 51    12
# 52    12
# 53     8
# 54    16
# 55     8
# 56     9
# 57    15
# 58    17
# 59    14
# 60    10
# 61     8
# 62    11
# 63     9
# 64    10
# 65     8
# 66     7
# 67     9
# 68     4
# 69     3
# 70     4
# 71     3
# 74     1
# 76     1
# 77     1
# Name: output, dtype: int64

# %%
print(data_merge.groupby(['class'])['output'].count())
data_merge.groupby(['class'])['output'].count().plot(kind="pie")
plt.show()
# Out:
# class
# 0    133
# 1    160
# Name: output, dtype: int64

# %%
data=data_merge.drop(["sex","cp","trtbps","chol","fbs","restecg","thalachh","exng","oldpeak","slp","caa","thall","output"],axis=1)
data.head(10)
# Out:
#     age  class
# 0    63      1
# 1    37      1
# 2    41      1
# 3    56      1
# 4    57      1
# 10   54      1
# 11   48      1
# 12   49      1
# 13   64      1
# 14   58      1

# %%
x=data_merge["age"]
y=data_merge["thalachh"]

# %%
data=data.sample(frac=1)
data.head(10)
# Out:
#      age  class
# 25    71      1
# 143   67      1
# 97    53      0
# 82    60      1
# 84    69      0
# 118   46      1
# 153   66      1
# 43    53      1
# 121   59      1
# 12    49      1

# %%
data.isnull().sum()
# Out:
# age      0
# class    0
# dtype: int64

# %%
from sklearn.model_selection import train_test_split as ttp
import re
import string

# %%
x_train,x_test,y_train,y_test=ttp(x,y,test_size=0.25,random_state=0)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
vector=TfidfVectorizer()
x_train=x_train.astype(str)
x_test=x_test.astype(str)
xv_train=vector.fit_transform(x_train)
xv_test=vector.transform(x_test)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report
import seaborn as sns
LR=LogisticRegression()
LR.fit(xv_train,y_train)
accuracy=LR.score(xv_test,y_test).round(2)
print("accuracy is",accuracy)
pred_LR= LR.predict(xv_test)
print(classification_report(y_test,pred_LR))
cm=confusion_matrix(y_test,pred_LR)
print(cm)
sns.heatmap(cm,cmap="Blues",annot=True)
# Out:
# accuracy is 0.01
#               precision    recall  f1-score   support
#
#          105       0.00      0.00      0.00         1
#          108       0.00      0.00      0.00         1
#          109       0.00      0.00      0.00         1
#          113       0.00      0.00      0.00         1
#          114       0.00      0.00      0.00         2
#          116       0.00      0.00      0.00         1
#          120       0.00      0.00      0.00         2
#          123       0.00      0.00      0.00         2
#          125       0.00      0.00      0.00         2
#          126       0.00      0.00      0.00         1
#          129       0.00      0.00      0.00         1
#          130       0.00      0.00      0.00         3
#          131       0.00      0.00      0.00         1
#          132       0.00      0.00      0.00         0
#          133       0.00      0.00      0.00         1
#          136       0.00      0.00      0.00         2
# ...
